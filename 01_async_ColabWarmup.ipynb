# %% [markdown]
# #Google Colab/Python Warm-Up
#
# In this warm-up activity, I'll...
# - Overview Google Colab environment, including saving/sharing options
# - Demo writing Python code, commenting, and using markdown
# - Do a for loop and if statement example.
# - Import packages
# - Read and write csv files with Pandas
# - Explore and visualize a dataset with Pandas and Matplotlib
# - Google to figure out how to do something

# %% [markdown]
# #The Google Colab Environment
# 1. Code/Text Blocks
# 2. File Name
# 3. Saving/Sharing Options (Google Drive, wisc account, naming conventions)
# 4. Menu
# 5. ToC/Search/Variables/Files

# %% [markdown]
# #Code, Comments, and Markdown
#
# Code blocks use Python: Below I'll demo:
# 1. Variables
# 2. Lists
# 3. Adding comments
# 4. Printing output
# 5. for statement
# 6. if statement

# %% [markdown]
# Text blocks use "Markdown" https://colab.research.google.com/notebooks/markdown_guide.ipynb

# %% [markdown]
# #Importing and using packages
#
# 1. importing numpy, pandas, and matplotlib
# 2. what happens if you didn't import properly

# %% [markdown]
# #Reading and writing csv files
#
# 1. Reading & writing cereal.csv with pandas (download cereal.csv at this link: https://uwmadison.box.com/s/9p5inyo0r7lgwlyf167s8dujaj116gmc)
# 2. Other ways available, too: https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92

# %% [markdown]
# #Exploring and Plotting Data
#
# 1. simple plots with matplotlib
# 2. plotting cereal data
# 3. other summary stats with pandas

# %% [markdown]
# #Googling to figure something out
#
# Ultimately, technology changes too fast for me to teach you well. Googling is a skill! Let's try:
#
# What would you do if you want to figure out how convert the "fiber" column to a list object called "fiber_list"?
#
# What would you do if you only want the columns from "calories" to "cups" (and no others) as a DataFrame object?

# %%
x = 1
y = 2
z = x + y
my_list = [x,y,z]

# %%
# practice for and if-statements
for i in my_list: 
  if i > 1:
   print(i)
# Out:
# 2
# 3

# %% [markdown]
# #heading 1
# ## heading 2
# ## heading 3
# - bullet points
# 1. more bullet points
#
# indicate math with dollar signs: $x= y$

# %%
# import packages
import numpy as np # general scientific computing stuff
import pandas as pd # for data
import matplotlib.pyplot as plt # for plotting

# %%
np.sqrt(9)
# Out:
# 3.0

# %%
# access csv. cereal file
cereal = pd.read_csv("cereal.csv", sep = ";")
type(cereal)
# Out:
# pandas.core.frame.DataFrame

# %%
# writing csv file
cereal.to_csv("cereal2.csv")

# %%
# exploring and plotting data
x = [1,2,3,4,5]
y = [1,2,4,8,16]

#plt.plot(x,y)
plt.hist(y)

#plot data fat and calories
cereal.plot.scatter(x = "fat", y = "calories")

cereal.hist("calories")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6eb51a9650>]],
#       dtype=object)

# %%
# covert fiber column to list
fiber_list = cereal["fiber"].tolist()

# %%
# extract columns from calories to cups
caltocups_df = cereal.iloc[:,3:15]
caltocups_df
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups
# 0       3     1.0  0.33
# ...
